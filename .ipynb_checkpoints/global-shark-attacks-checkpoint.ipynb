# %% [markdown]
# # Reunion Island is a shark attack spot!
#
#  According to the International Shark Attack File, from 2011 (when the island began to experience an increase in negative shark/human interaction rates) until 2016, Reunion Island was the location for 16% of the world’s fatal shark attacks – 7 out of 43 –  the same amount as South Africa, a country that is almost 500 times the size of Reunion and has 70 times more inhabitants.
#
# https://surfsimply.com/interviews/a-reunion-of-sharks/
# https://mundo.sputniknews.com/europa/201808011080852241-porque-hay-tantos-ataques-de-tiburones-en-isla-reunion/

# %% [markdown]
# ### Libraries and opening the file:
# First, let's import the libraries we need. After that, we will open the file:

# %%
# Interesting info: https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/

# %%
import chardet
import pandas as pd
import matplotlib.pyplot as plt
import src.functions as f

# %%
with open('./input/global_shark_attacks.csv', 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large


df = pd.read_csv('./input/global_shark_attacks.csv', encoding=result['encoding'])

# %% [markdown]
# Let's have a look:

# %%
display(df.head(10))
# Out:
#     Case Number       Date  Year        Type        Country  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked            USA
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked            USA
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked            USA
# 3    2016.09.17  17-Sep-16  2016  Unprovoked      AUSTRALIA
# 4    2016.09.15  16-Sep-16  2016  Unprovoked      AUSTRALIA
# 5  2016.09.15.R  15-Sep-16  2016        Boat      AUSTRALIA
# 6    2016.09.11  11-Sep-16  2016  Unprovoked            USA
# 7    2016.09.07  07-Sep-16  2016  Unprovoked            USA
# 8    2016.09.06  06-Sep-16  2016  Unprovoked  NEW CALEDONIA
# 9  2016.09.05.b  05-Sep-16  2016  Unprovoked            USA
#
#                 Area                                         Location  \
# 0            Florida                 New Smyrna Beach, Volusia County
# 1            Florida                 New Smyrna Beach, Volusia County
# 2            Florida                 New Smyrna Beach, Volusia County
# ...

# %% [markdown]
# I will remove some columns that I do not find useful for my analysis:

# %%
# I have realized that some columns are repeated or do not have any value for my analysis. I am going to remove them.

year_df = df.drop(columns=['Case Number','Date','Unnamed: 22','Unnamed: 23','original order','Case Number.2','Case Number.1','href','href formula','pdf','Investigator or Source',])

# %%
year_df.head(10)
# Out:
#    Year        Type        Country               Area  \
# 0  2016  Unprovoked            USA            Florida
# 1  2016  Unprovoked            USA            Florida
# 2  2016  Unprovoked            USA            Florida
# 3  2016  Unprovoked      AUSTRALIA           Victoria
# 4  2016  Unprovoked      AUSTRALIA           Victoria
# 5  2016        Boat      AUSTRALIA  Western Australia
# 6  2016  Unprovoked            USA            Florida
# 7  2016  Unprovoked            USA             Hawaii
# 8  2016  Unprovoked  NEW CALEDONIA     North Province
# 9  2016  Unprovoked            USA     South Carolina
#
#                                           Location         Activity  \
# 0                 New Smyrna Beach, Volusia County          Surfing
# 1                 New Smyrna Beach, Volusia County          Surfing
# 2                 New Smyrna Beach, Volusia County          Surfing
# 3                                 Thirteenth Beach          Surfing
# ...

# %%
#count_country = year_df.groupby(['Country']).size()

# %%
attacks_y_c = year_df.groupby(['Year','Country'])[['Type']].count()
attacks_y_c = attacks_y_c.sort_values(['Year','Type'], ascending=[False,False])
attacks_y_c.rename(columns={'Type':'Attacks'}, inplace=True)

# %%
display(attacks_y_c)
# Out:
#                     Attacks
# Year Country
# 2016 USA                 52
#      AUSTRALIA           23
#      NEW CALEDONIA        5
#      BAHAMAS              4
#      SOUTH AFRICA         3
# ...                     ...
# 0    SEYCHELLES           1
#      SINGAPORE            1
#      SPAIN                1
#      SRI LANKA            1
#      VENEZUELA            1
#
# [1803 rows x 1 columns]

# %% [markdown]
# We are going to choose the range of years we want to show in the DataFrame:

# %%
year_list = f.year_range()
year_list.reverse()
# Out:
# Please choose the first year of the year range:
# 2011
# Now choose the last one:
# 2016

# %%
print(year_list)
# Out:
# [2016, 2015, 2014, 2013, 2012, 2011]

# %%
attacks_per_year = attacks_y_c.loc[year_list, : ]
attacks_per_year.rename(columns={'Type':'Attacks'}, inplace=True)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also

    display(attacks_per_year)
# Out:
#                                  Attacks
# Year Country
# 2016 USA                              52
#      AUSTRALIA                        23
#      NEW CALEDONIA                     5
#      BAHAMAS                           4
#      SOUTH AFRICA                      3
#      SPAIN                             2
#      BRAZIL                            1
#      CAPE VERDE                        1
#      CAYMAN ISLANDS                    1
#      CHINA                             1
#      COLUMBIA                          1
#      DOMINICAN REPUBLIC                1
#      EGYPT                             1
#      FRENCH POLYNESIA                  1
#      Fiji                              1
#      INDONESIA                         1
#      JAPAN                             1
#      NEW ZEALAND                       1
#      REUNION                           1
#      UNITED ARAB EMIRATES              1
# 2015 USA                              72
# ...

# %%
for i in year_list:
    y_i = attacks_per_year.loc[i]
    y_i.plot(kind='bar')
    plt.title("Year "+str(i))
    plt.ylabel("Number of attacks")

# %%
df_mean = attacks_per_year.groupby('Country')[['Attacks']].mean()
df_mean_sorted = df_mean.sort_values(['Attacks'], ascending=[False]).head(5)

# %%
display(df_mean_sorted)
# Out:
#                 Attacks
# Country
# USA           60.166667
# AUSTRALIA     24.666667
# SOUTH AFRICA   7.000000
# BAHAMAS        3.500000
# REUNION        3.166667

# %%
c_a_d = df_mean_sorted.assign(population_density = [34,3,39,47,340])

# %%
display(c_a_d)
# Out:
#                 Attacks  population_density
# Country
# USA           60.166667                  34
# AUSTRALIA     24.666667                   3
# SOUTH AFRICA   7.000000                  39
# BAHAMAS        3.500000                  47
# REUNION        3.166667                 340

# %%
c_a_d_km = c_a_d.assign(coastline_km = [19924,25760,2798,3542,207])

# %%
display(c_a_d_km)
# Out:
#                 Attacks  population_density  coastline_km
# Country
# USA           60.166667                  34         19924
# AUSTRALIA     24.666667                   3         25760
# SOUTH AFRICA   7.000000                  39          2798
# BAHAMAS        3.500000                  47          3542
# REUNION        3.166667                 340           207

# %%
c_a_d_km['attack_coastline_ratio'] = c_a_d_km['coastline_km']/c_a_d_km['Attacks']
c_a_d_km = c_a_d_km.sort_values(['attack_coastline_ratio'], ascending=[True])

# %%
display(c_a_d_km)
# Out:
#                 Attacks  population_density  coastline_km  \
# Country
# REUNION        3.166667                 340           207
# USA           60.166667                  34         19924
# SOUTH AFRICA   7.000000                  39          2798
# BAHAMAS        3.500000                  47          3542
# AUSTRALIA     24.666667                   3         25760
#
#               attack_coastline_ratio
# Country
# REUNION                    65.368421
# USA                       331.146814
# SOUTH AFRICA              399.714286
# BAHAMAS                  1012.000000
# AUSTRALIA                1044.324324

# %%
export_csv = c_a_d_km.to_csv('./output/reunion_attacks.csv')
